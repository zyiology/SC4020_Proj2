# %%
import bz2
import csv
import io
import re
import random
from collections.abc import Generator
import os
from lxml import etree
from tqdm import tqdm

import numpy as np
import pandas as pd
from nltk.corpus import words

# %%
# FUNCTIONS FOR READING WIKI DATA: TAKEN FROM https://luizvbo.github.io/post/loading-wikipedia-data-with-python/
import wiki_dump

# %%
# Replace with the path to your index and dump files
index_file_path = 'data/enwiki-latest-pages-articles-multistream-index.txt.bz2'
offsets_file_path = 'data/offsets.txt'
dump_file_path = 'data/enwiki-latest-pages-articles-multistream.xml.bz2'
output_csv_path = 'data/articles_items.csv'

english_words = set(words.words())

# %% [raw]
# # don't run this cell will take ages (press esc+r/esc+y to disable/enable cells)
#
# with open(output_csv_path, 'w', newline='', encoding='utf-8') as csvfile:
#     csvwriter = csv.writer(csvfile)
#     offsets = wiki_dump.get_page_offsets(index_file_path, offsets_file_path)
#     for stream in wiki_dump.get_bz2_byte_str(dump_file_path, offsets):
#         for page in wiki_dump.process_pages(stream):
#             unique_words = wiki_dump.get_unique_words(text=page, dictionary=english_words)
#             csvwriter.writerow(unique_words)

# %% [raw]
# if __name__ == "__main__":
#     filename = "output.csv"
#     chunk_size = 1000  # Adjust this based on your available memory and dataset size.
#     min_support = 5
#
#     data_chunks = load_data_chunked(filename, chunk_size)
#     frequent_itemsets = apriori_chunked(data_chunks, min_support)
#
#     print("Frequent Itemsets:")
#     for itemset in frequent_itemsets:
#         print(itemset)

# %%
from dask.distributed import Client

client = Client(n_workers=6, threads_per_worker=2)  # Adjust based on your CPU
client
# Out:
# <Client: 'tcp://127.0.0.1:58591' processes=6 threads=12, memory=31.91 GiB>

# %%
import apriori_chunked

#%time apriori_chunked.apriori_disk('data/combined.csv',1000)
#%time apriori_chunked.apriori_disk('data/output_5.csv',40000)
# %time apriori_chunked.apriori_disk('data/articles_items.csv_worker_0.csv',500)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Task exception was never retrieved
# future: <Task finished name='Task-2231' coro=<Client._gather.<locals>.wait() done, defined at C:\Users\zhiyi\.conda\envs\SC4020\Lib\site-packages\distributed\client.py:2196> exception=AllExit()>
# Traceback (most recent call last):
#   File "C:\Users\zhiyi\.conda\envs\SC4020\Lib\site-packages\distributed\client.py", line 2205, in wait
#     raise AllExit()
# distributed.client.AllExit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed eval>:1
#
# File ~\PyCharmProjects\SC4020\SC4020_Proj2\apriori_chunked.py:25, in apriori_disk(data_file, min_support)
#      22 pruned_candidates = prune_candidates(candidates, freq_itemsets)
#      23 print(pruned_candidates)
# ---> 25 freq_new_level = get_frequent_item_sets(data_file, pruned_candidates, min_support)
#      27 if not freq_new_level:
#      28     break
#
# File ~\PyCharmProjects\SC4020\SC4020_Proj2\apriori_chunked.py:86, in get_frequent_item_sets(data_file, item_sets, min_support)
#      82 def get_frequent_item_sets(data_file, item_sets, min_support):
#      84     text = db.read_text(data_file, blocksize="100MB")
# ---> 86     results = text.map(count_itemsets_in_line, item_sets).fold(combine_counts).compute()
#      88     filtered_item_sets = {frozenset(key): value for key, value in results.items() if value > min_support}
#      90     return filtered_item_sets
#
# File ~\.conda\envs\SC4020\Lib\site-packages\dask\base.py:310, in DaskMethodsMixin.compute(self, **kwargs)
#     286 def compute(self, **kwargs):
#     287     """Compute this dask collection
#     288
#     289     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     308     dask.compute
#     309     """
# --> 310     (result,) = compute(self, traverse=False, **kwargs)
#     311     return result
#
# File ~\.conda\envs\SC4020\Lib\site-packages\dask\base.py:595, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     592     keys.append(x.__dask_keys__())
#     593     postcomputes.append(x.__dask_postcompute__())
# --> 595 results = schedule(dsk, keys, **kwargs)
#     596 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~\.conda\envs\SC4020\Lib\site-packages\distributed\client.py:3243, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3241         should_rejoin = False
#    3242 try:
# -> 3243     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    3244 finally:
#    3245     for f in futures.values():
#
# File ~\.conda\envs\SC4020\Lib\site-packages\distributed\client.py:2368, in Client.gather(self, futures, errors, direct, asynchronous)
#    2366 except ValueError:
#    2367     local_worker = None
# -> 2368 return self.sync(
#    2369     self._gather,
#    2370     futures,
#    2371     errors=errors,
#    2372     direct=direct,
#    2373     local_worker=local_worker,
#    2374     asynchronous=asynchronous,
#    2375 )
#
# File ~\.conda\envs\SC4020\Lib\site-packages\distributed\utils.py:351, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     349     return future
#     350 else:
# --> 351     return sync(
#     352         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     353     )
#
# File ~\.conda\envs\SC4020\Lib\site-packages\distributed\utils.py:414, in sync(loop, func, callback_timeout, *args, **kwargs)
#     412 else:
#     413     while not e.is_set():
# --> 414         wait(10)
#     416 if error:
#     417     typ, exc, tb = error
#
# File ~\.conda\envs\SC4020\Lib\site-packages\distributed\utils.py:403, in sync.<locals>.wait(timeout)
#     401 def wait(timeout):
#     402     try:
# --> 403         return e.wait(timeout)
#     404     except KeyboardInterrupt:
#     405         loop.add_callback(cancel)
#
# File ~\.conda\envs\SC4020\Lib\threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File ~\.conda\envs\SC4020\Lib\threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
