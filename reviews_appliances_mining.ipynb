# %%
from collections import defaultdict
import dask.distributed
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from apriori_general_v2 import apriori_disk, check_itemsets
import numpy as np
import os
import pickle
import datetime

# %%
count_dict = defaultdict(int)

#setup stuff
client = dask.distributed.Client(n_workers=6, threads_per_worker=1)  # Adjust based on your CPU
nltk_stopwords = stopwords.words('english')
with open('additional_stopwords.txt', 'r') as file:
    extra_stopwords = [line.strip() for line in file.readlines()]

extra_stopwords.extend(nltk_stopwords)
extra_stopwords.extend(['links', 'external', 'see', 'may', 'refer', 'link', 'wa'])

porter_stemmer = PorterStemmer()
extra_stopwords_stemmed = [porter_stemmer.stem(word) for word in extra_stopwords]
stopwords_set = set(extra_stopwords_stemmed)

# %%
# data = 'data/combined_stemmed.csv'
# block_size = "100MB"

data = 'data/appliances_reviews_transactions.txt'
block_size = "200KB"

# min_supports_list = np.arange(start=0.5, stop=0.15, step=--0.05)

min_supports_list = [0.46, 0.38, 0.3]

for min_support in min_supports_list:
    
    print(f"Testing min_support = {min_support}")
    directory = f"data/appliancesreviews/minsupp_{min_support}"
    if not os.path.exists(directory):
        os.mkdir(directory)

    start_time = datetime.datetime.now()

    # run the apriori disk function
    frequent_itemsets, string_mapping = apriori_disk(data_file=data,
                                                     exclude=stopwords_set,
                                                     min_support_percent=min_support,
                                                     blocksize=block_size,
                                                     client=client)
    
    end_time = datetime.datetime.now()

    # if function returns nothing, don't need to continue
    if not frequent_itemsets or not string_mapping:
        continue

    # if you want to recreate the list with the original strings
    with open(f"{directory}/itemsets_and_supports.txt", 'w') as f:
        for freq_itemset, support in frequent_itemsets.items():
            # Suppose you have a set of integers called int_set
            reconstructed_strings = set(key for key, value in string_mapping.items() if value in freq_itemset)
            f.write(f"{reconstructed_strings}: {support}\n")

    # the frequent itemsets are the keys of the frequent_itemsets dictionary
    freq_itemsets_list = list(frequent_itemsets.keys())

    # for clustering purposes, find if each itemset is present in each line
    itemset_features = check_itemsets(data, freq_itemsets_list, string_mapping, block_size, client=client)

    # save all variables so don't need to re-run script + for clustering
    with open(f'{directory}/frequent_itemsets.pkl', 'wb') as f:
        pickle.dump(frequent_itemsets, f)

    with open(f'{directory}/itemset_features.pkl', 'wb') as f:
        pickle.dump(itemset_features, f)

    with open(f'{directory}/itemset_list.pkl', 'wb') as f:
        pickle.dump(freq_itemsets_list, f)

    with open(f'{directory}/string_mapping.pkl', 'wb') as f:
        pickle.dump(string_mapping, f)

    with open(f'{directory}/log.txt', 'w') as f:

        f.write("started at " + start_time.strftime("%Y-%m-%d %H:%M:%S") + '\n')
        f.write("finished at " + end_time.strftime("%Y-%m-%d %H:%M:%S") + '\n')
        f.write("number of freq itemsets: " + str(len(freq_itemsets_list)) + '\n')
        f.write("length of longest itemset: " + str(len(freq_itemsets_list[-1])))
# Out:
# Testing min_support = 0.46
# no rows:  2269
# First pass completed
# Frequent Itemsets Level 1 completed
# 15 itemsets found
# generating candidates
# size of total pairs: 0.8828125KB
# scattered sublists
# 100 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 2 completed
# 36 itemsets found
#
# generating candidates
# size of total pairs: 5.2890625KB
# scattered sublists
# 39 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 3 completed
# 34 itemsets found
#
# generating candidates
# size of total pairs: 4.6640625KB
# scattered sublists
# 13 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 4 completed
# 9 itemsets found
#
# generating candidates
# size of total pairs: 0.3515625KB
# 0 candidates generated
# No more valid candidates to be found at level 5!
# Testing min_support = 0.38
# no rows:  2269
# First pass completed
# Frequent Itemsets Level 1 completed
# 27 itemsets found
# generating candidates
# size of total pairs: 2.7890625KB
# scattered sublists
# 346 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 2 completed
# 103 itemsets found
#
# generating candidates
# size of total pairs: 46.0390625KB
# scattered sublists
# 183 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 3 completed
# 150 itemsets found
#
# generating candidates
# size of total pairs: 93.6015625KB
# scattered sublists
# 101 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 4 completed
# 99 itemsets found
#
# generating candidates
# size of total pairs: 40.8828125KB
# scattered sublists
# 28 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 5 completed
# 27 itemsets found
#
# generating candidates
# size of total pairs: 2.7890625KB
# scattered sublists
# 2 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 6 completed
# 2 itemsets found
#
# generating candidates
# size of total pairs: 0.0703125KB
# 0 candidates generated
# No more valid candidates to be found at level 7!
# Testing min_support = 0.3
# no rows:  2269
# First pass completed
# Frequent Itemsets Level 1 completed
# 41 itemsets found
# generating candidates
# size of total pairs: 6.7578125KB
# scattered sublists
# 815 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 2 completed
# 290 itemsets found
#
# generating candidates
# size of total pairs: 342.8203125KB
# scattered sublists
# 1065 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 3 completed
# 795 itemsets found
#
# generating candidates
# size of total pairs: 2540.5703125KB
# scattered sublists
# 1134 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 4 completed
# 1120 itemsets found
#
# generating candidates
# size of total pairs: 5150.7578125KB
# scattered sublists
# 927 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 5 completed
# 927 itemsets found
#
# generating candidates
# size of total pairs: 3617.4453125KB
# scattered sublists
# 490 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 6 completed
# 490 itemsets found
#
# generating candidates
# size of total pairs: 990.0390625KB
# scattered sublists
# 172 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 7 completed
# 172 itemsets found
#
# generating candidates
# size of total pairs: 118.5703125KB
# scattered sublists
# 38 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 8 completed
# 38 itemsets found
#
# generating candidates
# size of total pairs: 5.9765625KB
# scattered sublists
# 4 candidates generated
# checking frequency of itemsets...
# Frequent Itemsets Level 9 completed
# 4 itemsets found
#
# generating candidates
# size of total pairs: 0.1015625KB
# 0 candidates generated
# No more valid candidates to be found at level 10!

# %%
print(itemset_features)
# Out:
# [[ True  True  True ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]

# %%
print(freq_itemsets_list)
# Out:
# [frozenset({0}), frozenset({1}), frozenset({2}), frozenset({3}), frozenset({4}), frozenset({5}), frozenset({6}), frozenset({7}), frozenset({8}), frozenset({9}), frozenset({10}), frozenset({11}), frozenset({12}), frozenset({13}), frozenset({14}), frozenset({15}), frozenset({16}), frozenset({17}), frozenset({18}), frozenset({19}), frozenset({20}), frozenset({21}), frozenset({22}), frozenset({23}), frozenset({24}), frozenset({25}), frozenset({26}), frozenset({27}), frozenset({28}), frozenset({29}), frozenset({30}), frozenset({31}), frozenset({32}), frozenset({33}), frozenset({34}), frozenset({35}), frozenset({36}), frozenset({37}), frozenset({38}), frozenset({39}), frozenset({40}), frozenset({2, 4}), frozenset({1, 3}), frozenset({0, 1}), frozenset({1, 2}), frozenset({1, 4}), frozenset({3, 6}), frozenset({8, 6}), frozenset({16, 17}), frozenset({11, 14}), frozenset({3, 12}), frozenset({8, 17}), frozenset({12, 14}), frozenset({16, 12}), frozenset({16, 15}), frozenset({8, 12}), frozenset({17, 13}), frozenset({10, 6}), frozenset({17, 11}), frozenset({17, 6}), frozenset({6, 15}), frozenset({8, 10}), frozenset({16, 3}), frozenset({11, 12}), frozenset({6, 14}), frozenset({17, 12}), frozenset({16, 11}), frozenset({11, 15}), frozenset({12, 15}), frozenset({14, 15}), frozenset({16, 9}), frozenset({16, 6}), frozenset({11, 6}), frozenset({12, 6}), frozenset({16, 14}), frozenset({12, 7}), frozenset({20, 6}), frozenset({0, 12}), frozenset({16, 5}), frozenset({0, 16}), frozenset({0, 5}), frozenset({17, 4}), frozenset({0, 8}), frozenset({22, 23}), frozenset({8, 23}), frozenset({8, 22}), frozenset({0, 23}), frozenset({19, 31}), frozenset({1, 33}), frozenset({29, 31}), frozenset({24, 30}), frozenset({0, 29}), frozenset({24, 37}), frozenset({1, 19}), frozenset({24, 5}), frozenset({24, 32}), frozenset({25, 34}), frozenset({32, 26}), frozenset({34, 12}), frozenset({37, 30}), frozenset({27, 37}), frozenset({32, 28}), frozenset({33, 6}), frozenset({1, 15}), frozenset({26, 23}), frozenset({1, 7}), frozenset({37, 6}), frozenset({32, 12}), frozenset({1, 28}), frozenset({24, 33}), frozenset({25, 23}), frozenset({8, 32}), frozenset({24, 20}), frozenset({10, 29}), frozenset({6, 23}), frozenset({1, 5}), frozenset({24, 29}), frozenset({20, 29}), frozenset({0, 31}), frozenset({36, 6}), frozenset({32, 9}), frozenset({0, 15}), frozenset({16, 30}), frozenset({27, 20}), frozenset({8, 27}), frozenset({24, 35}), frozenset({3, 29}), frozenset({37, 23}), frozenset({30, 23}), frozenset({19, 6}), frozenset({12, 20}), frozenset({28, 29}), frozenset({27, 29}), frozenset({32, 30}), frozenset({9, 37}), frozenset({24, 26}), frozenset({26, 34}), frozenset({19, 29}), frozenset({16, 1}), frozenset({34, 15}), frozenset({19, 37}), frozenset({16, 23}), frozenset({9, 29}), frozenset({24, 7}), frozenset({29, 6}), frozenset({10, 23}), frozenset({32, 25}), frozenset({24, 34}), frozenset({12, 23}), frozenset({3, 5}), frozenset({15, 31}), frozenset({34, 37}), frozenset({34, 19}), frozenset({35, 12}), frozenset({0, 34}), frozenset({1, 30}), frozenset({33, 31}), frozenset({24, 27}), frozenset({8, 20}), frozenset({27, 23}), frozenset({8, 26}), frozenset({12, 31}), frozenset({12, 29}), frozenset({27, 28}), frozenset({32, 37}), frozenset({32, 19}), frozenset({0, 28}), frozenset({16, 27}), frozenset({0, 27}), frozenset({25, 31}), frozenset({16, 29}), frozenset({16, 28}), frozenset({32, 15}), frozenset({8, 37}), frozenset({5, 6}), frozenset({1, 34}), frozenset({24, 3}), frozenset({32, 31}), frozenset({37, 7}), frozenset({7, 23}), frozenset({1, 27}), frozenset({26, 6}), frozenset({36, 23}), frozenset({24, 12}), frozenset({34, 23}), frozenset({12, 5}), frozenset({24, 9}), frozenset({32, 34}), frozenset({8, 31}), frozenset({0, 24}), frozenset({29, 15}), frozenset({19, 23}), frozenset({6, 31}), frozenset({32, 33}), frozenset({33, 23}), frozenset({27, 15}), frozenset({0, 20}), frozenset({29, 7}), frozenset({8, 34}), frozenset({24, 6}), frozenset({26, 31}), frozenset({29, 30}), frozenset({5, 29}), fro ...
# 2023-11-22 20:41:30,696 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 20:41:30,699 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 20:41:30,700 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 20:41:30,702 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 20:41:30,705 - distributed.nanny - WARNING - Restarting worker
# 2023-11-22 20:41:30,707 - distributed.nanny - WARNING - Restarting worker
